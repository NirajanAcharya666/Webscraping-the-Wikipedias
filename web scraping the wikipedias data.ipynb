# %%
import pandas as pd

# %%
url="https://en.wikipedia.org/wiki/Wikipedia:Fundraising_statistics"
tables=pd.read_html(url)

# %%
tables
# Out:
# [       Year Source        Revenue       Expenses    Asset rise   Total assets
#  0   2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
#  1   2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
#  2   2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
#  3   2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
#  4   2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#  5   2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
#  6   2015/16    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
#  7   2014/15    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
#  8   2013/14    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
#  9   2012/13    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
#  10  2011/12    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# ...

# %%
type(tables)
# Out:
# list

# %%
len(tables)
# Out:
# 1

# %%
tables[0].head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570

# %%
fundraising= tables[0]

# %%
fundraising
# Out:
#        Year Source        Revenue       Expenses    Asset rise   Total assets
# 0   2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1   2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2   2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3   2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4   2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 5   2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 6   2015/16    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 7   2014/15    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 8   2013/14    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 9   2012/13    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 10  2011/12    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# ...

# %%
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570

# %%
type(fundraising)
# Out:
# pandas.core.frame.DataFrame

# %%
fundraising.dtypes
# Out:
# Year            object
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# dtype: object

# %% [markdown]
# <h3>Check is there any Null values or not</h3>

# %%
fundraising.isna().any()
# Out:
# Year            False
# Source          False
# Revenue         False
# Expenses        False
# Asset rise      False
# Total assets    False
# dtype: bool

# %% [markdown]
# <h1>Removing the dollar from revenue colums and create own column</h1>

# %%
fundraising['Rev']=fundraising['Revenue'].str[2:]

# %%
fundraising
# Out:
#        Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0   2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1   2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2   2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3   2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4   2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 5   2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 6   2015/16    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 7   2014/15    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 8   2013/14    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 9   2012/13    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 10  2011/12    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# ...

# %%
fundraising.dtypes
# Out:
# Year            object
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# Rev             object
# dtype: object

# %% [markdown]
# <p>Now, its turn to convert the commas because it is making the data types as a string</p>

# %%
fundraising['Rev']=fundraising['Rev'].str.replace(",","")

# %%
fundraising
# Out:
#        Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0   2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1   2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2   2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3   2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4   2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 5   2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 6   2015/16    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 7   2014/15    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 8   2013/14    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 9   2012/13    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 10  2011/12    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# ...

# %%
fundraising.dtypes
# Out:
# Year            object
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# Rev             object
# dtype: object

# %% [markdown]
# <p>Still, the datatypes is in object form. To convert this into numeric. Lets use to_numeric function of pandas</p>

# %%
fundraising['Rev']=pd.to_numeric(fundraising['Rev'])

# %%
fundraising.dtypes
# Out:
# Year            object
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# Rev              int64
# dtype: object

# %%
fundraising
# Out:
#        Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0   2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1   2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2   2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3   2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4   2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 5   2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 6   2015/16    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 7   2014/15    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 8   2013/14    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 9   2012/13    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 10  2011/12    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# ...

# %%
fundraising['Total_assets']=fundraising['Total assets'].str[2:]

# %%
fundraising
# Out:
#        Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0   2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1   2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2   2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3   2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4   2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 5   2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 6   2015/16    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 7   2014/15    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 8   2013/14    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 9   2012/13    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 10  2011/12    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# ...

# %%
fund=fundraising.drop(['Revenue','Total assets'], axis=1)

# %%
fund
# Out:
#        Year Source       Expenses    Asset rise        Rev Total_assets
# 0   2021/22    PDF  $ 145,970,915   $ 8,173,996  154686521  239,351,532
# 1   2020/21    PDF  $ 111,839,819  $ 50,861,811  162886686  231,177,536
# 2   2019/20    PDF  $ 112,489,397  $ 14,674,300  129234327  180,315,725
# 3   2018/19    PDF   $ 91,414,010  $ 30,691,855  120067266  165,641,425
# 4   2017/18    PDF   $ 81,442,265  $ 21,619,373  104505783  134,949,570
# 5   2016/17    PDF   $ 69,136,758  $ 21,547,402   91242418  113,330,197
# 6   2015/16    PDF   $ 65,947,465  $ 13,962,497   81862724   91,782,795
# 7   2014/15    PDF   $ 52,596,782  $ 24,345,277   75797223   77,820,298
# 8   2013/14    PDF   $ 45,900,745   $ 8,285,897   52465287   53,475,021
# 9   2012/13    PDF   $ 35,704,796  $ 10,260,066   48635408   45,189,124
# 10  2011/12    PDF   $ 29,260,652  $ 10,736,914   38479665   34,929,058
# 11  2010/11    PDF   $ 17,889,794   $ 9,649,413   24785092   24,192,144
# ...

# %%
fund['Total_assets']=fund['Total_assets'].str.replace(",","")

# %%
fund
# Out:
#        Year Source       Expenses    Asset rise        Rev Total_assets
# 0   2021/22    PDF  $ 145,970,915   $ 8,173,996  154686521    239351532
# 1   2020/21    PDF  $ 111,839,819  $ 50,861,811  162886686    231177536
# 2   2019/20    PDF  $ 112,489,397  $ 14,674,300  129234327    180315725
# 3   2018/19    PDF   $ 91,414,010  $ 30,691,855  120067266    165641425
# 4   2017/18    PDF   $ 81,442,265  $ 21,619,373  104505783    134949570
# 5   2016/17    PDF   $ 69,136,758  $ 21,547,402   91242418    113330197
# 6   2015/16    PDF   $ 65,947,465  $ 13,962,497   81862724     91782795
# 7   2014/15    PDF   $ 52,596,782  $ 24,345,277   75797223     77820298
# 8   2013/14    PDF   $ 45,900,745   $ 8,285,897   52465287     53475021
# 9   2012/13    PDF   $ 35,704,796  $ 10,260,066   48635408     45189124
# 10  2011/12    PDF   $ 29,260,652  $ 10,736,914   38479665     34929058
# 11  2010/11    PDF   $ 17,889,794   $ 9,649,413   24785092     24192144
# ...

# %% [markdown]
# <h3>lets find the data types</h3>

# %%
fund.dtypes
# Out:
# Year            object
# Source          object
# Expenses        object
# Asset rise      object
# Rev              int64
# Total_assets    object
# dtype: object

# %%
fund['Total_assets']=pd.to_numeric(fund['Total_assets'])

# %%
fund
# Out:
#        Year Source       Expenses    Asset rise        Rev  Total_assets
# 0   2021/22    PDF  $ 145,970,915   $ 8,173,996  154686521     239351532
# 1   2020/21    PDF  $ 111,839,819  $ 50,861,811  162886686     231177536
# 2   2019/20    PDF  $ 112,489,397  $ 14,674,300  129234327     180315725
# 3   2018/19    PDF   $ 91,414,010  $ 30,691,855  120067266     165641425
# 4   2017/18    PDF   $ 81,442,265  $ 21,619,373  104505783     134949570
# 5   2016/17    PDF   $ 69,136,758  $ 21,547,402   91242418     113330197
# 6   2015/16    PDF   $ 65,947,465  $ 13,962,497   81862724      91782795
# 7   2014/15    PDF   $ 52,596,782  $ 24,345,277   75797223      77820298
# 8   2013/14    PDF   $ 45,900,745   $ 8,285,897   52465287      53475021
# 9   2012/13    PDF   $ 35,704,796  $ 10,260,066   48635408      45189124
# 10  2011/12    PDF   $ 29,260,652  $ 10,736,914   38479665      34929058
# 11  2010/11    PDF   $ 17,889,794   $ 9,649,413   24785092      24192144
# ...

# %%
fund['Asset_rise']=fund['Asset rise'].str[2:]

# %%
fund['Asset_rise']=fund['Asset rise'].str.replace(",","")

# %%
fund
# Out:
#        Year Source       Expenses    Asset rise        Rev  Total_assets  \
# 0   2021/22    PDF  $ 145,970,915   $ 8,173,996  154686521     239351532
# 1   2020/21    PDF  $ 111,839,819  $ 50,861,811  162886686     231177536
# 2   2019/20    PDF  $ 112,489,397  $ 14,674,300  129234327     180315725
# 3   2018/19    PDF   $ 91,414,010  $ 30,691,855  120067266     165641425
# 4   2017/18    PDF   $ 81,442,265  $ 21,619,373  104505783     134949570
# 5   2016/17    PDF   $ 69,136,758  $ 21,547,402   91242418     113330197
# 6   2015/16    PDF   $ 65,947,465  $ 13,962,497   81862724      91782795
# 7   2014/15    PDF   $ 52,596,782  $ 24,345,277   75797223      77820298
# 8   2013/14    PDF   $ 45,900,745   $ 8,285,897   52465287      53475021
# 9   2012/13    PDF   $ 35,704,796  $ 10,260,066   48635408      45189124
# 10  2011/12    PDF   $ 29,260,652  $ 10,736,914   38479665      34929058
# 11  2010/11    PDF   $ 17,889,794   $ 9,649,413   24785092      24192144
# ...

# %% [markdown]
# <p>Convert the  date column to numeric</p>

# %%
fundraising
# Out:
#        Year        Revenue       Expenses    Asset rise   Total assets  \
# 0   2021/22  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1   2020/21  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2   2019/20  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3   2018/19  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4   2017/18  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 5   2016/17   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 6   2015/16   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 7   2014/15   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 8   2013/14   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 9   2012/13   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 10  2011/12   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 11  2010/11   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# ...

# %%
fundraising
# Out:
#    Year        Revenue       Expenses    Asset rise   Total assets        Rev  \
# 0    20  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532  154686521
# 1    20  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536  162886686
# 2    20  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725  129234327
# 3    20  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425  120067266
# 4    20  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570  104505783
# 5    20   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197   91242418
# 6    20   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795   81862724
# 7    20   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298   75797223
# 8    20   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021   52465287
# 9    20   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124   48635408
# 10   20   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058   38479665
# ...

# %%
del fundraising['Year']

# %%
fundraising
# Out:
#           Revenue       Expenses    Asset rise   Total assets        Rev  \
# 0   $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532  154686521
# 1   $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536  162886686
# 2   $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725  129234327
# 3   $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425  120067266
# 4   $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570  104505783
# 5    $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197   91242418
# 6    $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795   81862724
# 7    $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298   75797223
# 8    $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021   52465287
# 9    $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124   48635408
# 10   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058   38479665
# 11   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144   24785092
# ...

# %%
fundraising.head()
# Out:
#          Revenue       Expenses    Asset rise   Total assets        Rev  \
# 0  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532  154686521
# 1  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536  162886686
# 2  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725  129234327
# 3  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425  120067266
# 4  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570  104505783
#
#   Total_assets
# 0  239,351,532
# 1  231,177,536
# 2  180,315,725
# 3  165,641,425
# 4  134,949,570

# %%
fundraising['Expenses']=pd.to_numeric(fundraising['Expenses'].str[2:].str.replace(",",""))

# %%
fundraising
# Out:
#           Revenue   Expenses    Asset rise   Total assets        Rev  \
# 0   $ 154,686,521  145970915   $ 8,173,996  $ 239,351,532  154686521
# 1   $ 162,886,686  111839819  $ 50,861,811  $ 231,177,536  162886686
# 2   $ 129,234,327  112489397  $ 14,674,300  $ 180,315,725  129234327
# 3   $ 120,067,266   91414010  $ 30,691,855  $ 165,641,425  120067266
# 4   $ 104,505,783   81442265  $ 21,619,373  $ 134,949,570  104505783
# 5    $ 91,242,418   69136758  $ 21,547,402  $ 113,330,197   91242418
# 6    $ 81,862,724   65947465  $ 13,962,497   $ 91,782,795   81862724
# 7    $ 75,797,223   52596782  $ 24,345,277   $ 77,820,298   75797223
# 8    $ 52,465,287   45900745   $ 8,285,897   $ 53,475,021   52465287
# 9    $ 48,635,408   35704796  $ 10,260,066   $ 45,189,124   48635408
# 10   $ 38,479,665   29260652  $ 10,736,914   $ 34,929,058   38479665
# 11   $ 24,785,092   17889794   $ 9,649,413   $ 24,192,144   24785092
# 12   $ 17,979,312   10266793   $ 6,310,964   $ 14,542,731   17979312
# ...

# %%
fundraising['Asset rise']=pd.to_numeric(fundraising['Asset rise'].str[2:].str.replace(",",""))

# %%
fundraising
# Out:
#           Revenue   Expenses  Asset rise   Total assets        Rev  \
# 0   $ 154,686,521  145970915     8173996  $ 239,351,532  154686521
# 1   $ 162,886,686  111839819    50861811  $ 231,177,536  162886686
# 2   $ 129,234,327  112489397    14674300  $ 180,315,725  129234327
# 3   $ 120,067,266   91414010    30691855  $ 165,641,425  120067266
# 4   $ 104,505,783   81442265    21619373  $ 134,949,570  104505783
# 5    $ 91,242,418   69136758    21547402  $ 113,330,197   91242418
# 6    $ 81,862,724   65947465    13962497   $ 91,782,795   81862724
# 7    $ 75,797,223   52596782    24345277   $ 77,820,298   75797223
# 8    $ 52,465,287   45900745     8285897   $ 53,475,021   52465287
# 9    $ 48,635,408   35704796    10260066   $ 45,189,124   48635408
# 10   $ 38,479,665   29260652    10736914   $ 34,929,058   38479665
# 11   $ 24,785,092   17889794     9649413   $ 24,192,144   24785092
# 12   $ 17,979,312   10266793     6310964   $ 14,542,731   17979312
# ...

# %%
fundraising=fundraising.drop(['Revenue','Total assets'],axis=1)

# %%
fundraising
# Out:
#      Expenses  Asset rise        Rev Total_assets
# 0   145970915     8173996  154686521  239,351,532
# 1   111839819    50861811  162886686  231,177,536
# 2   112489397    14674300  129234327  180,315,725
# 3    91414010    30691855  120067266  165,641,425
# 4    81442265    21619373  104505783  134,949,570
# 5    69136758    21547402   91242418  113,330,197
# 6    65947465    13962497   81862724   91,782,795
# 7    52596782    24345277   75797223   77,820,298
# 8    45900745     8285897   52465287   53,475,021
# 9    35704796    10260066   48635408   45,189,124
# 10   29260652    10736914   38479665   34,929,058
# 11   17889794     9649413   24785092   24,192,144
# 12   10266793     6310964   17979312   14,542,731
# 13    5617236     3053599    8658006    8,231,767
# 14    3540724     3519886    5032981    5,178,168
# 15    2077843      654066    2734909    1,658,282
# 16     791907      736132    1508039    1,004,216
# 17     177670      211418     379088      268,084
# ...

# %%
fundraising.dtypes
# Out:
# Expenses         int64
# Asset rise       int64
# Rev              int64
# Total_assets    object
# dtype: object

# %%
fundraising['Total_assets']=pd.to_numeric(fundraising['Total_assets'].str[2:].str.replace(",",""))

# %%
fundraising
# Out:
#      Expenses  Asset rise        Rev  Total_assets
# 0   145970915     8173996  154686521       9351532
# 1   111839819    50861811  162886686       1177536
# 2   112489397    14674300  129234327        315725
# 3    91414010    30691855  120067266       5641425
# 4    81442265    21619373  104505783       4949570
# 5    69136758    21547402   91242418       3330197
# 6    65947465    13962497   81862724        782795
# 7    52596782    24345277   75797223        820298
# 8    45900745     8285897   52465287        475021
# 9    35704796    10260066   48635408        189124
# 10   29260652    10736914   38479665        929058
# 11   17889794     9649413   24785092        192144
# 12   10266793     6310964   17979312        542731
# 13    5617236     3053599    8658006        231767
# 14    3540724     3519886    5032981        178168
# 15    2077843      654066    2734909        658282
# 16     791907      736132    1508039          4216
# ...

# %%
fundraising.dtypes
# Out:
# Expenses        int64
# Asset rise      int64
# Rev             int64
# Total_assets    int64
# dtype: object

# %% [markdown]
# <h3>Visualize the data</h3>

# %%
fundraising.plot()
# Out:
# <Axes: >
